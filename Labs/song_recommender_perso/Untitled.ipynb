# %%
import requests
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import config

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,client_secret=config.client_secret))

# %%
sp.audio_features("2Fxmhks0bxGSBdJ92vM42m")
# Out:
# [{'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'type': 'audio_features',
#   'id': '2Fxmhks0bxGSBdJ92vM42m',
#   'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m',
#   'duration_ms': 194088,
#   'time_signature': 4}]

# %%
playlist = sp.user_playlists('spotify')

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/users/spotify/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': 'Glass Animals are on top of the Hottest 50!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#    'id': '37i9dQZF1DXcBWIGoYBM5M',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003c60697be6c1717cdcde2f3d4',
#      'width': None}],
#    'name': "Today's Top Hits",
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTYzMTU1OTA3NiwwMDAwMDRlODAwMDAwMTdiZTA3ZmM5YmIwMDAwMDE3YmNkMTU4OTE0',
# ...

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(playlist["items"])
# Out:
# 50

# %%
playlists_list = []
for i in range(0,len(playlist["items"])):
    playlists_list.append([playlist["items"][i]["name"],playlist["items"][i]["id"]])
print(playlists_list)
# Out:
# [["Today's Top Hits", '37i9dQZF1DXcBWIGoYBM5M'], ['RapCaviar', '37i9dQZF1DX0XUsuxWHRQd'], ['Hot Country', '37i9dQZF1DX1lVhptIYRda'], ['¡Viva Latino!', '37i9dQZF1DX10zKzsJ2jva'], ['New Music Friday', '37i9dQZF1DX4JAvHpjipBk'], ['Peaceful Piano', '37i9dQZF1DX4sWSpwq3LiO'], ['Are & Be', '37i9dQZF1DX4SBhb3fqCJd'], ['Rock Classics', '37i9dQZF1DWXRqgorJj26U'], ['mint', '37i9dQZF1DX4dyzvuaRJ0n'], ['Rock This', '37i9dQZF1DXcF6B6QPhFDv'], ['New Music Friday', '37i9dQZF1DWXJfnUiYjUKT'], ['just hits', '37i9dQZF1DXcRXFNfZr7Tp'], ['All Out 00s', '37i9dQZF1DX4o1oenSJRJd'], ['All Out 90s', '37i9dQZF1DXbTxeAdrVG2l'], ['All Out 80s', '37i9dQZF1DX4UtSsGT1Sbe'], ['All Out 70s', '37i9dQZF1DWTJ7xPn4vNaz'], ['All Out 60s', '37i9dQZF1DXaKIA8E7WcJj'], ['All Out 50s', '37i9dQZF1DWSV3Tk4GO2fq'], ['Soft Pop Hits', '37i9dQZF1DWTwnEm1IYyoj'], ['Signed XOXO', '37i9dQZF1DX2A29LI7xHn1'], ['Most Necessary', '37i9dQZF1DX2RxBh64BHjQ'], ['Gold School', '37i9dQZF1DWVA1Gq4XHa6U'], ['Get Turnt', '37i9dQZF1DWY4xHQp97fN6'],
# ...

# %%
playlists_ids = []
for i in range(0,len(playlists_list)):
    playlists_ids.append(playlists_list[i][1])
playlists_ids
# Out:
# ['37i9dQZF1DXcBWIGoYBM5M',
#  '37i9dQZF1DX0XUsuxWHRQd',
#  '37i9dQZF1DX1lVhptIYRda',
#  '37i9dQZF1DX10zKzsJ2jva',
#  '37i9dQZF1DX4JAvHpjipBk',
#  '37i9dQZF1DX4sWSpwq3LiO',
#  '37i9dQZF1DX4SBhb3fqCJd',
#  '37i9dQZF1DWXRqgorJj26U',
#  '37i9dQZF1DX4dyzvuaRJ0n',
#  '37i9dQZF1DXcF6B6QPhFDv',
#  '37i9dQZF1DWXJfnUiYjUKT',
#  '37i9dQZF1DXcRXFNfZr7Tp',
#  '37i9dQZF1DX4o1oenSJRJd',
#  '37i9dQZF1DXbTxeAdrVG2l',
#  '37i9dQZF1DX4UtSsGT1Sbe',
#  '37i9dQZF1DWTJ7xPn4vNaz',
#  '37i9dQZF1DXaKIA8E7WcJj',
#  '37i9dQZF1DWSV3Tk4GO2fq',
#  '37i9dQZF1DWTwnEm1IYyoj',
#  '37i9dQZF1DX2A29LI7xHn1',
#  '37i9dQZF1DX2RxBh64BHjQ',
#  '37i9dQZF1DWVA1Gq4XHa6U',
#  '37i9dQZF1DWY4xHQp97fN6',
#  '37i9dQZF1DWX3387IZmjNa',
#  '37i9dQZF1DWYkaDif7Ztbp',
#  '37i9dQZF1DX5hR0J49CmXC',
#  '37i9dQZF1DXan38dNVDdl4',
#  '37i9dQZF1DWSvKsRPPnv5o',
#  '37i9dQZF1DWUVpAXiEPK8P',
#  '37i9dQZF1DX0Tkc6ltcBfU',
#  '37i9dQZF1DX1YPTAhwehsC',
#  '37i9dQZF1DWTggY0yqBxES',
#  '37i9dQZF1DX0HRj9P7NxeE',
#  '37i9dQZF1DWT6SJaitNDax',
# ...

# %%
sp.playlist_items("37i9dQZF1DXcBWIGoYBM5M",fields=["items","track"])
# Out:
# {'items': [{'added_at': '2021-09-13T18:51:16Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tIP7SsRs7vjIcLrU85W8J'},
#        'href': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J',
#        'id': '2tIP7SsRs7vjIcLrU85W8J',
#        'name': 'The Kid LAROI',
#        'type': 'artist',
#        'uri': 'spotify:artist:2tIP7SsRs7vjIcLrU85W8J'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
# ...
