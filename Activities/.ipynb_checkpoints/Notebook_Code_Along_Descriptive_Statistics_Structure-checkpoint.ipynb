# %% [markdown]
# # Population vs Sample

# %% [markdown]
# Let's explore in this notebook the difference between both.
#
# To this end, we're going to generate a random set of 100.000 integers.
#
# Then we will try to guess the mean of the total population using SAMPLES taken at random from the population

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#***seed*** helps to "freeze" the random function. If there is no seed, everytime this notebook is run, random choice will
#output a different choice of 1000 out of 100000. And if we want to share this notebook, we need to have the 
#"same random" values (which we then freeze using seed)

np.random.seed(12)
population = np.random.choice(1000,100000) # 100K random integer numbers between [0,1000]
population.shape

population_mean = np.mean(population)
print("Population mean: {:.2f}".format(population_mean))
print("Population mean: {}".format(population_mean))
print("Population mean rounded: ",round(population_mean,2))
# Out:
# Population mean: 499.45
# Population mean: 499.44726
# Population mean rounded:  499.45

# %%
type(population)
# Out:
# numpy.ndarray

# %% [markdown]
# *Now* let's take 20 random samples of 1000 picks from this population and see how each sample mean changes.
#
# Create a dictionary in which the keys have the name: 'sample_1', 'sample_2',..... and so on. As values, every key should contain the sample of 1000 random numbers from the population

# %%
{ 'sample_' + str(numbers): np.random.choice(population,5).tolist() for numbers in range(20)}
# Out:
# {'sample_0': [415, 26, 903, 7, 659],
#  'sample_1': [137, 163, 738, 476, 381],
#  'sample_2': [697, 211, 923, 271, 558],
#  'sample_3': [59, 322, 721, 741, 779],
#  'sample_4': [585, 637, 142, 367, 664],
#  'sample_5': [356, 290, 116, 400, 832],
#  'sample_6': [129, 486, 335, 884, 839],
#  'sample_7': [672, 553, 46, 208, 776],
#  'sample_8': [979, 220, 482, 267, 797],
#  'sample_9': [512, 412, 384, 130, 330],
#  'sample_10': [533, 542, 140, 377, 552],
#  'sample_11': [770, 50, 382, 824, 788],
#  'sample_12': [83, 960, 892, 919, 599],
#  'sample_13': [381, 672, 554, 247, 6],
#  'sample_14': [435, 785, 542, 695, 155],
#  'sample_15': [166, 604, 322, 983, 884],
#  'sample_16': [399, 441, 666, 276, 102],
#  'sample_17': [488, 867, 110, 674, 114],
#  'sample_18': [741, 750, 253, 816, 208],
#  'sample_19': [238, 259, 582, 805, 630]}

# %%
#samples = {}

samples = {'sample_' + str(i+1): np.random.choice(population, size = 1000).tolist() for i in range(20)}
print(samples)
# Out:
# {'sample_1': [513, 343, 76, 668, 928, 158, 472, 570, 618, 566, 855, 504, 267, 832, 841, 775, 934, 248, 732, 393, 998, 535, 503, 186, 160, 421, 220, 502, 807, 743, 704, 302, 970, 491, 149, 163, 15, 328, 768, 129, 495, 321, 567, 587, 769, 28, 16, 23, 621, 711, 717, 50, 200, 853, 92, 922, 312, 395, 240, 703, 978, 750, 552, 843, 0, 936, 634, 87, 722, 4, 291, 635, 824, 503, 123, 255, 511, 519, 211, 123, 172, 444, 692, 213, 539, 103, 992, 470, 849, 112, 620, 458, 655, 39, 596, 95, 248, 759, 645, 688, 789, 279, 220, 879, 212, 516, 782, 915, 623, 764, 700, 292, 861, 86, 879, 490, 919, 861, 46, 452, 542, 868, 563, 376, 380, 572, 407, 906, 805, 996, 938, 15, 688, 926, 77, 113, 812, 753, 779, 158, 968, 65, 361, 304, 413, 53, 684, 444, 34, 453, 993, 95, 720, 346, 697, 81, 872, 133, 67, 527, 237, 341, 944, 662, 491, 650, 500, 873, 247, 411, 98, 706, 88, 179, 56, 610, 689, 945, 872, 898, 370, 845, 271, 776, 207, 227, 852, 796, 746, 527, 862, 785, 956, 918, 282, 701, 866, 71, 35, 396, 710, 548, 220, 12, 796, 187, 514, 151, 485, 941, 533, 101, 9, 857, 704, 363, 752, 336, 330, 10, 39, 382, 544, 849, 755, 549, 219, 386, 214, 884, 598, 833, 8, 176, 714, 136, 219, 707, 435, 609, 626, 258, 730, 967, 267, 535, 242, 389, 92, 48, 100, 415, 617, 484, 429, 95, 706, 674, 640, 547, 515, 121, 912, 48, 490, 113, 594, 902, 842, 784, 752, 197, 769, 278, 161, 185, 916, 815, 6, 450, 483, 238, 228, 634, 846, 40, 519, 407, 490, 876, 519, 489, 992, 259, 180, 692, 952, 751, 247, 970, 344, 256, 172, 361, 260, 596, 239, 984, 772, 381, 396, 918, 478, 262, 71, 75, 617, 184, 982, 731, 269, 250, 543, 491, 790, 685, 932, 438, 404, 108, 185, 480, 796, 747, 23, 200, 633, 338, 476, 836, 408, 398, 883, 853, 643, 196, 43, 400, 628, 706, 18, 685, 213, 617, 804, 966, 660, 769, 704, 217, 341, 340, 418, 950, 11, 438, 553, 787, 334, 485, 845, 959, 415, 600, 910, 387, 691, 996, 540, 735, 205, 164, 86, 610, 567, 732, 846, 389, 947, 358, 630, 305, 741, 996, 605, 613, 598, 787, 106, 113, 762, 987, 525, 523, 791, 137, 413, 957, 209, 28, 948, 631, 761, 50, 707, 475, 365, 699, 294, 793, 268, 146, 237, 975, 553, 192, 984, 35, 669, 443, 427, 715, 471, 536, 956, 955, 733, 976, 19, 210, 501, 54, 262, 345, 475, 794, 51, 989, 259, 371, 507, 255, 763, 975, 516, 344, 212, 807, 525, 346, 620, 182, 489, 129, 373, 842, 227, 214, 38, 693, 531, 575, 726, 386, 799, 641, 230, 759, 802, 869, 989, 87, 833, 297, 314, 712, 828, 400, 205, 55, 663, 854, 376, 796, 343, 233, 298, 687, 557, 8, 707, 24, 111, 471, 340, 237, 94, 888, 895, 958, 538, 875, 129, 406, 576, 909, 320, 996, 974, 620, 728, 458, 694, 801, 43, 301, 745, 619, 170, 742, 415, 78, 982, 535, 912, 701, 45, 344, 926, 126, 772, 534, 627, 752, 650, 122, 306, 806, 700, 745, 136, 790, 460, 839, 369, 270, 574, 196, 306, 97, 429, 730, 294, 844, 984, 954, 135, 422, 384, 664, 195, 775, 141, 391, 682, 449, 93, 918, 342, 409, 278, 119, 498, 439, 279, 182, 315, 220, 306, 838, 616, 185, 173, 771, 862, 229, 118, 545, 713, 680, 503, 596, 92, 350, 385, 481, 57, 612, 560, 684, 724, 934, 944, 459, 959, 370, 533, 257, 744, 202, 927, 6, 443, 417, 163, 827, 877, 563, 89, 577, 401, 424, 650, 884, 382, 976, 686, 143, 662, 490, 236, 543, 33, 680, 406, 559, 581, 33, 920, 809, 117, 39, 265, 396, 154, 304, 567, 740, 140, 292, 254, 274, 904, 240, 394, 31, 729, 997, 16, 827, 424, 382, 362, 813, 182, 224, 8, 177, 999, 913, 123, 371, 869, 557, 452, 693, 862, 691, 140, 649, 336, 373, 342, 949, 878, 791, 169, 108, 881, 967, 207, 263, 693, 708, 628, 242, 657, 526, 646, 234, 198, 835, 397, 283, 407, 277, 731, 520, 56, 61, 13, 296, 267, 177, 859, 885, 420, 129, 133, 296, 246, 362, 854, 822, 83, 336, 375, 613, 9, 158, 954, 636, 166, 482, 58, 841, 321, 979, 651, 244, 261, 917, 50, 520, 139, 470, 38, 240, 223, 996, 979, 935, 456, 442, 352, 37, 463, 804, 939, 598, 516, 953, 246, 235, 885, 927, 640, 441, 543, 777, 539, 814, 504, 271, 923, 248, 698, 502, 367, 398, 621, 651, 925, 863, 857, 493, 209, 475, 820, 204, 727, 621, 838, 620, 730, 524, 795, 786, 383, 996, 548, 580, 370, 694, 710, 8 ...

# %% [markdown]
# Now, compute the mean of each sample.

# %%
#format scripture
x="Tatou"
y="Science"
print("Population mean: {} {}".format(x,y))

#note: the "":.2f" means: all values before comma but only 2 decimals
# Out:
# Population mean: Tatou Science

# %%
print("Population mean: {:.2f}".format(population_mean))

for key, values in samples.items():
    print("Sample {} has a mean of {}".format(key,np.mean(values)))
# Out:
# Population mean: 499.45
# Sample sample_1 has a mean of 499.945
# Sample sample_2 has a mean of 515.118
# Sample sample_3 has a mean of 492.874
# Sample sample_4 has a mean of 492.387
# Sample sample_5 has a mean of 499.672
# Sample sample_6 has a mean of 516.526
# Sample sample_7 has a mean of 494.4
# Sample sample_8 has a mean of 503.194
# Sample sample_9 has a mean of 491.275
# Sample sample_10 has a mean of 510.934
# Sample sample_11 has a mean of 496.84
# Sample sample_12 has a mean of 505.354
# Sample sample_13 has a mean of 503.495
# Sample sample_14 has a mean of 492.556
# Sample sample_15 has a mean of 489.343
# Sample sample_16 has a mean of 498.868
# Sample sample_17 has a mean of 481.839
# Sample sample_18 has a mean of 509.243
# Sample sample_19 has a mean of 495.58
# Sample sample_20 has a mean of 504.408

# %% [markdown]
# $\mu_{1}=x_{1}$
#
# $\mu_{2}=\frac{x_{1}+x_{2}}{2} = \frac{x_{1}}{2}+\frac{x_{2}}{2}=\frac{\mu_{1}}{2}+\frac{x_{2}}{2}$
#
# $\mu_{3}=\frac{x_{1}+x_{2}+x_{3}}{3}=\frac{x_{1}+x_{2}}{3}+\frac{x_{3}}{3}=\frac{2}{3}\frac{x_{1}+x_{2}}{2}+\frac{x_{3}}{3}=\frac{2}{3}\mu_{2}+\frac{x_{3}}{3}$
#
# $\mu_{n}=\frac{(n-1)}{n}\mu_{n-1}+\frac{x_{n}}{n}=\mu_{n-1}-\frac{\mu_{n-1}}{n}+\frac{x_{n}}{n}$

# %% [markdown]
# Now construct a pandas dataframe with the samples:

# %%
df = pd.DataFrame(samples)
df
# Out:
#      sample_1  sample_2  sample_3  sample_4  sample_5  sample_6  sample_7  \
# 0         513       559       102       170       205       575       879
# 1         343       935       784       754       311       168       362
# 2          76       422       850       204       720       475       856
# 3         668       329       968       106       257       880        36
# 4         928       989       734       484        49       745        22
# ..        ...       ...       ...       ...       ...       ...       ...
# 995       473       441       894       801       529       651       720
# 996       195       404       700       162       784        47       202
# 997       708        17       969       470       176       118       709
# 998       320       742       112       556        64       688       227
# 999       156       888       624         1       762       602        64
#
#      sample_8  sample_9  sample_10  sample_11  sample_12  sample_13  \
# 0         822       400        381        247        900        238
# 1         708       519        448        984        883        519
# 2         621        14        129        615        370        519
# 3          38       673        927        518         76         39
# 4         443       478        163        110        831        689
# ..        ...       ...        ...        ...        ...        ...
# 995       986       855        819        150        664        621
# 996       959       421        970         17        623        681
# 997       281       672        472        285        353         64
# 998       880       299        657        955        558        542
# 999       286       660        794        219        544        641
#
#      sample_14  sample_15  sample_16  sample_17  sample_18  sample_19  \
# 0          558        965        583        870        786        477
# 1          448        581         96         91        440        594
# 2          818        435        747         45        305        181
# 3          829        549        675        729        246        874
# 4          814        725        900        244        310        764
# ..         ...        ...        ...        ...        ...        ...
# 995        663        574        353        750        896        358
# 996        125        551        668        511        180        740
# 997        625        396        828        550        143        998
# 998        240        207        492        103        991        976
# 999        196        256          6        284         38        802
#
#      sample_20
# 0          322
# 1          687
# 2          217
# 3          399
# 4           35
# ..         ...
# 995         48
# 996         93
# 997        829
# 998        420
# 999        654
#
# [1000 rows x 20 columns]

# %%
df.describe().loc['mean']
# Out:
# sample_1     499.945
# sample_2     515.118
# sample_3     492.874
# sample_4     492.387
# sample_5     499.672
# sample_6     516.526
# sample_7     494.400
# sample_8     503.194
# sample_9     491.275
# sample_10    510.934
# sample_11    496.840
# sample_12    505.354
# sample_13    503.495
# sample_14    492.556
# sample_15    489.343
# sample_16    498.868
# sample_17    481.839
# sample_18    509.243
# sample_19    495.580
# sample_20    504.408
# Name: mean, dtype: float64

# %% [markdown]
# Now compute the means of each sample using "apply"

# %%
result = df.apply(np.mean)
print(result)
# Out:
# sample_1     499.945
# sample_2     515.118
# sample_3     492.874
# sample_4     492.387
# sample_5     499.672
# sample_6     516.526
# sample_7     494.400
# sample_8     503.194
# sample_9     491.275
# sample_10    510.934
# sample_11    496.840
# sample_12    505.354
# sample_13    503.495
# sample_14    492.556
# sample_15    489.343
# sample_16    498.868
# sample_17    481.839
# sample_18    509.243
# sample_19    495.580
# sample_20    504.408
# dtype: float64

# %% [markdown]
# Check the type of the previous object

# %%
type(result)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Use the previous `result` to create another dataframe in which the columns are the samples names and the row contains the mean of the sample using `transpose()`

# %%
means = pd.DataFrame(result).transpose()
means
# Out:
#    sample_1  sample_2  sample_3  sample_4  sample_5  sample_6  sample_7  \
# 0   499.945   515.118   492.874   492.387   499.672   516.526     494.4
#
#    sample_8  sample_9  sample_10  sample_11  sample_12  sample_13  sample_14  \
# 0   503.194   491.275    510.934     496.84    505.354    503.495    492.556
#
#    sample_15  sample_16  sample_17  sample_18  sample_19  sample_20
# 0    489.343    498.868    481.839    509.243     495.58    504.408

# %% [markdown]
# Add another column to the previous dataframe called 'population_mean' which contain the mean of the population

# %%
means['population_mean'] = population_mean
means
# Out:
#    sample_1  sample_2  sample_3  sample_4  sample_5  sample_6  sample_7  \
# 0   499.945   515.118   492.874   492.387   499.672   516.526     494.4
#
#    sample_8  sample_9  sample_10  ...  sample_12  sample_13  sample_14  \
# 0   503.194   491.275    510.934  ...    505.354    503.495    492.556
#
#    sample_15  sample_16  sample_17  sample_18  sample_19  sample_20  \
# 0    489.343    498.868    481.839    509.243     495.58    504.408
#
#    population_mean
# 0        499.44726
#
# [1 rows x 21 columns]

# %% [markdown]
# Add another row to the dataframe with the deviations from the population mean using the following steps:
#
# 1. Compute the difference between `result` and `population_mean`
# 2. Create a dataframe with the previous output.
# 3. Transpose the resulting dataframe.
# 3. Concat both dataframes.

# %%
population_mean -result
# Out:
# sample_1     -0.49774
# sample_2    -15.67074
# sample_3      6.57326
# sample_4      7.06026
# sample_5     -0.22474
# sample_6    -17.07874
# sample_7      5.04726
# sample_8     -3.74674
# sample_9      8.17226
# sample_10   -11.48674
# sample_11     2.60726
# sample_12    -5.90674
# sample_13    -4.04774
# sample_14     6.89126
# sample_15    10.10426
# sample_16     0.57926
# sample_17    17.60826
# sample_18    -9.79574
# sample_19     3.86726
# sample_20    -4.96074
# dtype: float64

# %%
new_df = pd.DataFrame( population_mean - result ).transpose()
new_df
# Out:
#    sample_1  sample_2  sample_3  sample_4  sample_5  sample_6  sample_7  \
# 0  -0.49774 -15.67074   6.57326   7.06026  -0.22474 -17.07874   5.04726
#
#    sample_8  sample_9  sample_10  sample_11  sample_12  sample_13  sample_14  \
# 0  -3.74674   8.17226  -11.48674    2.60726   -5.90674   -4.04774    6.89126
#
#    sample_15  sample_16  sample_17  sample_18  sample_19  sample_20
# 0   10.10426    0.57926   17.60826   -9.79574    3.86726   -4.96074

# %% [markdown]
# Use `pd.concat` in order to add the previous dataframe as another row to `final`. Remember to reset the index.

# %%
final = pd.concat([means, new_df],axis=0).reset_index(drop=True)
final
# Out:
#     sample_1   sample_2   sample_3   sample_4   sample_5   sample_6  \
# 0  499.94500  515.11800  492.87400  492.38700  499.67200  516.52600
# 1   -0.49774  -15.67074    6.57326    7.06026   -0.22474  -17.07874
#
#     sample_7   sample_8   sample_9  sample_10  ...  sample_12  sample_13  \
# 0  494.40000  503.19400  491.27500  510.93400  ...  505.35400  503.49500
# 1    5.04726   -3.74674    8.17226  -11.48674  ...   -5.90674   -4.04774
#
#    sample_14  sample_15  sample_16  sample_17  sample_18  sample_19  \
# 0  492.55600  489.34300  498.86800  481.83900  509.24300  495.58000
# 1    6.89126   10.10426    0.57926   17.60826   -9.79574    3.86726
#
#    sample_20  population_mean
# 0  504.40800        499.44726
# 1   -4.96074              NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# Let's obtain some basic plots

# %%
final.iloc[1,:-1].plot()
# Out:
# <AxesSubplot:>

# %%
final.iloc[1,:-1].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
final.iloc[1,:-1].describe()
# Out:
# count    20.000000
# mean     -0.245290
# std       8.947843
# min     -17.078740
# 25%      -5.197240
# 50%       0.177260
# 75%       6.652760
# max      17.608260
# Name: 1, dtype: float64

# %%
final.iloc[1,:-1].plot.box()
# Lower_wisker = Q1-1.5(Q3-Q1)
# Upper_wisker = Q3+1.5(Q3-Q1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Can you obtain which sample name has the most similar mean to the population mean?
#
# *Hint: use np.argmin()*

# %%
loc_min = np.argmin(np.abs(final.iloc[1,:-1]))
print("The minimum deviation is: {:.2f}".format(final.iloc[1,loc_min]))
print("wich correspondds to 'sample_{}'".format(loc_min+1))
# Out:
# The minimum deviation is: -0.22
# wich correspondds to 'sample_5'

# %%
final
# Out:
#     sample_1   sample_2   sample_3   sample_4   sample_5   sample_6  \
# 0  499.94500  515.11800  492.87400  492.38700  499.67200  516.52600
# 1   -0.49774  -15.67074    6.57326    7.06026   -0.22474  -17.07874
#
#     sample_7   sample_8   sample_9  sample_10  ...  sample_12  sample_13  \
# 0  494.40000  503.19400  491.27500  510.93400  ...  505.35400  503.49500
# 1    5.04726   -3.74674    8.17226  -11.48674  ...   -5.90674   -4.04774
#
#    sample_14  sample_15  sample_16  sample_17  sample_18  sample_19  \
# 0  492.55600  489.34300  498.86800  481.83900  509.24300  495.58000
# 1    6.89126   10.10426    0.57926   17.60826   -9.79574    3.86726
#
#    sample_20  population_mean
# 0  504.40800        499.44726
# 1   -4.96074              NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# Now get the coresponding column name

# %%
final.columns[loc_min]
# Out:
# 'sample_5'

# %% [markdown]
# What is the mean of the samples deviations?

# %%
print("The mean sample deviation is {:.2f}: ".format(np.mean(final.iloc[1,:-1])))
# Out:
# The mean sample deviation is -0.25:

# %% [markdown]
# What is the median of the deviations from the mean?

# %%
print("The median sample deviation is {:.2f}: ".format(np.median(final.iloc[1,:-1])))
# Out:
# The median sample deviation is 0.18:
